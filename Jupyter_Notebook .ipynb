# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mario Mompean Herrero**
#
# Actualmente estoy buscando trabajo como científico de datos o como físico ya que terminé mis estudios hace apenas unos meses

# %% [markdown]
# *Estoy interesado en la ciencia de datos ya que me parece una herramienta muy potente para nuestro día a día y para el futuro. Nos permite aprender y entender una gran cantidad de datos que para una persona sin estas herramientas nunca sacaría ninguna conclusión sobre ellos.*

# %% [markdown]
# ### En la celda siguiente incluyo la libreria de numpy para calcular el valor del coseno de cero y que me lo ponga en pantalla

# %%
import numpy as np

x=np.cos(0)
print('El coseno de 0 es :') ; print(x)
# Out:
# El coseno de 0 es :
# 1.0

# %% [markdown]
# 1. Desayuno
# 2. Comida
# 3. Cena
#
# | Desayuno | Comida  |  Cena |
# | ----     | ----    |  ---- |
# | Yogur    | Arroz    | Tortilla      |
# | Café     | Pollo    |     Fruta  |
